# %% [markdown]
# # Projeto 1 Matemática multivariada:

# %% [markdown]
# **Alunos:
# Luis Antonio Santana Rodrigues,
# Fernando Alzueta,
# Leonardo Merlin**

# %%
import math as m
import numpy as np
import matplotlib.pyplot as plt
from scipy.optimize import fsolve

# %%
def check(A,B):
    cond = True
    if A >= 8*m.pi:
        cond = False
    if m.sin(A/2) == 0:
        cond = False
    if m.sin(B/2) == 0:
        cond = False
    if m.sin(7*A/4) == 0:
        cond = False
    if m.sin(7*B/4) == 0:
        cond = False
    return cond

# %%
def fazGraf():
    # VALORES DE t
    t = np.linspace(0, 4*np.pi, 1000)

    # valores para x e y para cada valor de t
    x = 5*np.cos(t) - 3*np.cos(7*t/2)
    y = 5*np.sin(t) - 3*np.sin(7*t/2)
    return x,y


#Curva
x,y = fazGraf()
plt.plot(x, y)
plt.axis('equal')
plt.show()

# %% [markdown]
# ```python
# Pontos de auto insercecção:
# ```

# %%
pontos = []

# %% [markdown]
# * I) X + Y = 0.8Pi*

# %%
def f_proj(B,K):
    value = 10 * m.sin(B/2) * m.cos((1/2)*0.8* K * m.pi) - 6 * m.sin(7*B/4) * m.cos((7/4)* 0.8* K *m.pi)
    return value

# %%
def encontraRaiz(valores,K):
    todos = []
    # percorre todos os t em valores
    # analisa se o valor de f_proj(t) mudou de sinal
    # se mudou, calcula a raiz
    for i in range(len(valores)-1):
        #raiz = fsolve(f_proj, valores[i], args=(K))

        if f_proj(valores[i],K) * f_proj(valores[i+1],K) < 0:
            raiz = valores[i]
            todos.append(raiz)
    print(todos)
    return todos

# %%
valores = np.arange(0, 4*m.pi, 0.001)

solucoes = encontraRaiz(valores,1)
for B in solucoes:

    u = (B + 0.8 * m.pi)/2
    v = (-B + 0.8 * m.pi)/2

    print(u)
    print(v)

    A = u + v
    
    x = 5 * m.cos(u) - 3 * m.cos(7*u/2)
    y = 5 * m.sin(u) - 3 * m.sin(7*u/2)

    pontos.append([x,y])
    plt.plot(x, y, 'ro')   

#Curva
x,y = fazGraf()
plt.plot(x, y)
plt.axis('equal')
plt.show()
# Out:
# [5.681, 11.418000000000001]
# 4.097137061435918
# -1.5838629385640828
# 6.965637061435918
# -4.452362938564083

# %% [markdown]
# * I) X + Y = 1.6Pi*

# %%
valores = np.arange(0, 4*m.pi, 0.001)

solucoes = encontraRaiz(valores,2)
for B in solucoes:

    u = (B + 0.8 * 2 * m.pi)/2
    v = (-B + 0.8 * 2 * m.pi)/2

    print(u)
    print(v)

    A = u + v
    
    x = 5 * m.cos(u) - 3 * m.cos(7*u/2)
    y = 5 * m.sin(u) - 3 * m.sin(7*u/2)

    pontos.append([x,y])
    plt.plot(x, y, 'ro')   

#Curva
x,y = fazGraf()
plt.plot(x, y)
plt.axis('equal')
plt.show()
# Out:
# [1.1480000000000001, 6.885]
# 3.0872741228718343
# 1.9392741228718344
# 5.955774122871834
# -0.9292258771281654

# %% [markdown]
# *I)  X + Y = 2.4 Pi*

# %%
valores = np.arange(0, 4*m.pi, 0.001)

solucoes = encontraRaiz(valores,3)
K = 3
for B in solucoes:

    u = (B + 0.8 * K * m.pi)/2
    v = (-B + 0.8 * K * m.pi)/2

    print(u)
    print(v)

    A = u + v
    
    x = 5 * m.cos(u) - 3 * m.cos(7*u/2)
    y = 5 * m.sin(u) - 3 * m.sin(7*u/2)

    pontos.append([x,y])
    plt.plot(x, y, 'ro')   

#Curva
x,y = fazGraf()
plt.plot(x, y)
plt.axis('equal')
plt.show()
# Out:
# [5.681, 11.418000000000001]
# 6.610411184307752
# 0.9294111843077522
# 9.478911184307753
# -1.9390888156922483

# %%
#Curva
for ponto in pontos:
    plt.plot(ponto[0], ponto[1], 'ro')
x,y = fazGraf()
plt.plot(x, y)
plt.axis('equal')
plt.show()

# %%
pontos = []
raizes = []
for K in [1,2,3,4,5,6,7,8,9]:   
    valores = np.arange(0, 4*m.pi, 0.001)

    solucoes = encontraRaiz(valores,K)
    for B in solucoes:

        u = (B + 0.8 * K * m.pi)/2
        v = (-B + 0.8 * K * m.pi)/2

        #print(u)
        #print(v)

        A = u + v

        if(check(A,B)):
            if [u,v] not in raizes:
                raizes.append([u,v])
            x = 5 * m.cos(u) - 3 * m.cos(7*u/2)
            y = 5 * m.sin(u) - 3 * m.sin(7*u/2)

            pontos.append([x,y])
            plt.plot(x, y, 'ro')   

print("raizes: ", raizes)
#Curva
x,y = fazGraf()
plt.plot(x, y)
plt.axis('equal')
plt.show()
# Out:
# [5.681, 11.418000000000001]
# [1.1480000000000001, 6.885]
# [5.681, 11.418000000000001]
# [1.1480000000000001, 6.885]
# [5.681, 11.418000000000001]
# [1.1480000000000001, 6.885]
# [5.681, 11.418000000000001]
# [1.1480000000000001, 6.885]
# [5.681, 11.418000000000001]
# raizes:  [[4.097137061435918, -1.5838629385640828], [6.965637061435918, -4.452362938564083], [3.0872741228718343, 1.9392741228718344], [5.955774122871834, -0.9292258771281654], [6.610411184307752, 0.9294111843077522], [9.478911184307753, -1.9390888156922483], [5.600548245743669, 4.452548245743669], [8.469048245743668, 1.584048245743669], [9.123685307179587, 3.442685307179586], [11.992185307179586, 0.5741853071795857], [8.113822368615505, 6.9658223686155045], [10.982322368615504, 4.0973223686155045], [11.636959430051421, 5.95595943005142], [14.50545943005142, 3.08745943005142], [10.627096491487338, 9.479096491487338], [13.495596491487337, 6.610596491487338], [14.150233552923256, 8.469233552923255], [17.018733552923255, 5.600733552923255]]

# %% [markdown]
# ```python
# Pontos em que a reta tangente é vertical:
# ```

# %%
def fazGraf():
    # VALORES DE t
    t = np.linspace(0, 4*np.pi, 1000)

    # valores para x e y para cada valor de t
    x = 5*np.cos(t) - 3*np.cos(7*t/2)
    y = 5*np.sin(t) - 3*np.sin(7*t/2)

    xl = -5*np.sin(t) + 3*(7/2)*np.sin(7*t/2)
    yl = 5*np.cos(t) - 3*(7/2)*np.cos(7*t/2)
    return x,y, xl,yl



#Curva|
x,y,xl,yl = fazGraf()
plt.plot(x, y)
plt.plot(xl, yl)
plt.axis('equal')
plt.show()

# %%
# Equacao parametrizada:
# x = 5cos(t) - 3cos(7t/2)
# y = 5sen(t) - 3sen(7t/2)

#Derivada da equacao parametrizada:
# x' = -5sen(t) + 3*7/2*sen(7t/2)
# y' = 5cos(t) - 3*7/2*cos(7t/2)

raizes_vert = []

for t in (np.arange(0, 4*m.pi, 0.001)):

    xl = -5*m.sin(t) + 3*(7/2)*m.sin(7*t/2)
    yl = 5*m.cos(t) - 3*(7/2)*m.cos(7*t/2)

    if m.abs(xl) < 0.001 and m.abs(yl) > 0.001:
        raizes_vert.append(t)

raizes_vert
# Out:
# [0.0]

# %%
# Equacao parametrizada:
# x = 5cos(t) - 3cos(7t/2)
# y = 5sen(t) - 3sen(7t/2)

#Derivada da equacao parametrizada:
# x' = -5sen(t) + 3*7/2*sen(7t/2)
# y' = 5cos(t) - 3*7/2*cos(7t/2)

raizes_hor = []

for t in (np.arange(0, 4*m.pi, 0.001)):

    xl = -5*m.sin(t) + 3*(7/2)*m.sin(7*t/2)
    yl = 5*m.cos(t) - 3*(7/2)*m.cos(7*t/2)

    if m.abs(xl) < 0.001 and m.abs(yl) > 0.001:
        raizes_vert.append(t)

raizes_hor
# Out:
# []

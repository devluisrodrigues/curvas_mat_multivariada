# %% [markdown]
# # Projeto 1 Matemática multivariada:

# %% [markdown]
# **Alunos:
# Luis Antonio Santana Rodrigues,
# Fernando Alzueta,
# Leonardo Merlin**

# %%
import math as m
import numpy as np
import matplotlib.pyplot as plt
from scipy.optimize import fsolve

# %%
def fazGraf():
    # VALORES DE t
    t = np.linspace(0, 4*np.pi, 1000)

    # valores para x e y para cada valor de t
    x = 5*np.cos(t) - 3*np.cos(7*t/2)
    y = 5*np.sin(t) - 3*np.sin(7*t/2)
    return x,y


#Curva
x,y = fazGraf()
plt.plot(x, y)
plt.axis('equal')
plt.show()

# %% [markdown]
# ```python
# Pontos de auto insercecção:
# ```

# %% [markdown]
# * I) X + Y = 0.8Pi*

# %%
def f_proj(B):
    value = 10 * m.sin(B/2) * m.cos(0.4*m.pi) - 6 * m.sin(7*B/4) * m.cos(1.4*m.pi)
    return value

# %%
def encontraRaiz(valores):
    todos = []
    # percorre todos os t em valores
    # analisa se o valor de f_proj(t) mudou de sinal
    # se mudou, calcula a raiz
    for i in range(len(valores)-1):
        if f_proj(valores[i]) * f_proj(valores[i+1]) < 0:
            raiz = fsolve(f_proj, valores[i])
            todos.append(raiz)
    return todos

# %%
valores = np.arange(0, 4*m.pi, 0.001)

solucoes = encontraRaiz(valores)
for B in solucoes:
    u = (sol + 0.8 * m.pi)/2
    v = (-sol + 0.8 * m.pi)/2
    print(u)
    print(v)
    A = u + v
    x = 5 * m.cos(u) - 3 * m.cos(7*u/2)
    y = 5 * m.sin(u) - 3 * m.sin(7*u/2)
    plt.plot(x, y, 'ro')   

#Curva
x,y = fazGraf()
plt.plot(x, y)
plt.axis('equal')
plt.show()
# Out:
# 6.9661370614359175
# -4.452862938564083
# 6.9661370614359175
# -4.452862938564083

# %% [markdown]
# * I) X + Y = 0.8Pi*

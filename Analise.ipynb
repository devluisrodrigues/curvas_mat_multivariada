# %% [markdown]
# # Projeto 1 Matemática multivariada:

# %% [markdown]
# **Alunos:
# Luis Antonio Santana Rodrigues,
# Fernando Alzueta,
# Leonardo Merlin**

# %%
import math as m
import numpy as np
import matplotlib.pyplot as plt

# %%
# VALORES DE t
t = np.linspace(0, 4*np.pi, 1000)

# valores para x e y para cada valor de t
x = 5*np.cos(t) - 3*np.cos(7*t/2)
y = 5*np.sin(t) - 3*np.sin(7*t/2)

#Curva
plt.plot(x, y)
plt.axis('equal')
plt.show()

# %% [markdown]
# ```python
# Pontos de auto insercecção:
# ```

# %% [markdown]
# * I) X + Y = 0.8Pi*

# %%
def f_proj(B):
    eq = 10 * m.sin(B/2) * m.cos(0.4*m.pi) - 6 * m.sin(7*B/4) * m.cos(1.4*m.pi)
    return eq

# %%
valores = np.arange(0, 4*m.pi, 0.001)
for x in valores:

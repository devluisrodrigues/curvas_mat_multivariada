# %% [markdown]
# # Projeto 1 Matemática multivariada:
# ---

# %% [markdown]
# **Alunos:
# Luis Antonio Santana Rodrigues,
# Fernando Alzueta,
# Leonardo Merlin**
# ---
# ---

# %% [markdown]
# ---
# ---
# ### Bibliotecas do trabalho
# ---

# %%
import math as m
import numpy as np
import matplotlib.pyplot as plt
from scipy.optimize import fsolve

# %% [markdown]
# ---
# ---
# ---
# ## Parte 1: Funções
# ---

# %% [markdown]
# ### Função para testar se os valores para A e B estão dentro das condições de existência

# %%
def check(A,B):
    cond = True
    if A >= 8*m.pi:
        cond = False
    if m.sin(A/2) == 0:
        cond = False
    if m.sin(B/2) == 0:
        cond = False
    if m.sin(7*A/4) == 0:
        cond = False
    if m.sin(7*B/4) == 0:
        cond = False
    return cond

# %% [markdown]
# ---
# ### Função que faz o gráfico da curva

# %%
def fazGraf():
    # VALORES DE t
    t = np.linspace(0, 4*np.pi, 1000)

    # valores para x e y para cada valor de t
    x = 5*np.cos(t) - 3*np.cos(7*t/2)
    y = 5*np.sin(t) - 3*np.sin(7*t/2)
    return x,y


#Curva
x,y = fazGraf()
plt.plot(x, y)
plt.axis('equal')
plt.show()

# %% [markdown]
# ---
# ### Função que encontra as raizes de dada equação

# %%
def encontraRaiz(valores,K):
    todos = []
    # percorre todos os t em valores
    # analisa se o valor de f_proj(t) mudou de sinal
    # se mudou, calcula a raiz
    for i in range(len(valores)-1):
        #raiz = fsolve(f_proj, valores[i], args=(K))

        if f_proj(valores[i],K) * f_proj(valores[i+1],K) < 0:
            raiz = valores[i]
            todos.append(raiz)
            
    return todos

# %% [markdown]
# ---
# ### Função para inicializar a equação e variar em K

# %%
def f_proj(B,K):
    value = 10 * m.sin(B/2) * m.cos((1/2)*0.8* K * m.pi) - 6 * m.sin(7*B/4) * m.cos((7/4)* 0.8* K *m.pi)
    return value

# %% [markdown]
# ---
# ---
# ---
# ## Parte 2: Achando pontos e valores

# %% [markdown]
# ```python
# Pontos de auto insercecção:
# ```

# %%
pontos = []

# %% [markdown]
# ---
# ### Para: X + Y = 0.8Pi

# %%
valores = np.arange(0, 4*m.pi, 0.0001)

solucoes = encontraRaiz(valores,1)
for B in solucoes:

    u = (B + 0.8 * m.pi)/2
    v = (-B + 0.8 * m.pi)/2

    A = u + v
    
    x = 5 * m.cos(u) - 3 * m.cos(7*u/2)
    y = 5 * m.sin(u) - 3 * m.sin(7*u/2)

    pontos.append([x,y])
    plt.plot(x, y, 'ro')   

#Curva
x,y = fazGraf()
plt.plot(x, y)
plt.axis('equal')
plt.show()

# %% [markdown]
# ---
# ### Para: X + Y = 1.6Pi

# %%
valores = np.arange(0, 4*m.pi, 0.001)

solucoes = encontraRaiz(valores,2)
for B in solucoes:

    u = (B + 0.8 * 2 * m.pi)/2
    v = (-B + 0.8 * 2 * m.pi)/2

    A = u + v
    
    x = 5 * m.cos(u) - 3 * m.cos(7*u/2)
    y = 5 * m.sin(u) - 3 * m.sin(7*u/2)

    pontos.append([x,y])
    plt.plot(x, y, 'ro')   

#Curva
x,y = fazGraf()
plt.plot(x, y)
plt.axis('equal')
plt.show()

# %% [markdown]
# ---
# ### Para: X + Y = 2.4 Pi

# %%
valores = np.arange(0, 4*m.pi, 0.001)

solucoes = encontraRaiz(valores,3)
K = 3
for B in solucoes:

    u = (B + 0.8 * K * m.pi)/2
    v = (-B + 0.8 * K * m.pi)/2
    
    A = u + v
    
    x = 5 * m.cos(u) - 3 * m.cos(7*u/2)
    y = 5 * m.sin(u) - 3 * m.sin(7*u/2)

    pontos.append([x,y])
    plt.plot(x, y, 'ro')   

#Curva
x,y = fazGraf()
plt.plot(x, y)
plt.axis('equal')
plt.show()

# %%
#Curva
for ponto in pontos:
    plt.plot(ponto[0], ponto[1], 'ro')
x,y = fazGraf()
plt.plot(x, y)
plt.axis('equal')
plt.show()

# %%
pontos = []
raizes = []

with open('autoIntersec.txt', 'w') as f:
    f.write("Inicio\n")

for K in [1,2,3,4,5,6,7,8,9]:   
    valores = np.arange(0, 4*m.pi, 0.0001)

    solucoes = encontraRaiz(valores,K)
    for B in solucoes:

        u = (B + 0.8 * K * m.pi)/2
        v = (-B + 0.8 * K * m.pi)/2

        with open('autoIntersec.txt', 'a') as f:
            f.write(f"Para k igual a {round(K, 3)}, B vale {round(B,3)}, u vale {round(u,3)} e v vale {round(v,3)}"+"\n")
        print(f"Para k igual a {round(K,3)}, B vale {round(B,3)}, u vale {round(u,3)} e v vale {round(v,3)}")

        A = u + v

        if(check(A,B)):
            if [u,v] not in raizes:
                raizes.append([u,v])
            x = 5 * m.cos(u) - 3 * m.cos(7*u/2)
            y = 5 * m.sin(u) - 3 * m.sin(7*u/2)

            with open('autoIntersec.txt', 'a') as f:
                f.write(f"Para k igual a {round(K, 3)}, B vale {round(B, 3)} está nas condicões"+"\n")
                f.write(f"Para k igual a {round(K, 3)}, B vale {round(B, 3)}, x vale {round(x, 3)} e y vale {round(y, 3)}"+"\n")

            pontos.append([x,y])
            plt.plot(x, y, 'ro')
        with open('autoIntersec.txt', 'a') as f:
            f.write("\n")
    


print("raizes: \n", raizes)
#Curva
x,y = fazGraf()
plt.plot(x, y)
plt.axis('equal')
plt.show()
# Out:
# Para k igual a 1, B vale 5.681, u vale 4.097 e v vale -1.584
# Para k igual a 1, B vale 11.418, u vale 6.966 e v vale -4.452
# Para k igual a 2, B vale 1.148, u vale 3.087 e v vale 1.939
# Para k igual a 2, B vale 6.885, u vale 5.956 e v vale -0.929
# Para k igual a 3, B vale 5.681, u vale 6.61 e v vale 0.929
# Para k igual a 3, B vale 11.418, u vale 9.479 e v vale -1.939
# Para k igual a 4, B vale 1.148, u vale 5.601 e v vale 4.452
# Para k igual a 4, B vale 6.885, u vale 8.469 e v vale 1.584
# Para k igual a 5, B vale 5.681, u vale 9.124 e v vale 3.443
# Para k igual a 5, B vale 11.418, u vale 11.992 e v vale 0.574
# Para k igual a 6, B vale 1.148, u vale 8.114 e v vale 6.966
# Para k igual a 6, B vale 6.885, u vale 10.982 e v vale 4.097
# Para k igual a 7, B vale 5.681, u vale 11.637 e v vale 5.956
# Para k igual a 7, B vale 11.418, u vale 14.505 e v vale 3.087
# Para k igual a 8, B vale 1.148, u vale 10.627 e v vale 9.479
# Para k igual a 8, B vale 6.885, u vale 13.496 e v vale 6.61
# Para k igual a 9, B vale 5.681, u vale 14.15 e v vale 8.469
# Para k igual a 9, B vale 11.418, u vale 17.019 e v vale 5.601
# raizes:
#  [[4.097137061435918, -1.5838629385640828], [6.965637061435918, -4.452362938564083], [3.0874241228718344, 1.9391241228718346], [5.955924122871835, -0.9293758771281655], [6.610411184307752, 0.9294111843077522], [9.478911184307753, -1.9390888156922483], [5.600698245743669, 4.452398245743669], [8.46919824574367, 1.583898245743669], [9.123685307179587, 3.442685307179586], [11.992185307179586, 0.5741853071795857], [8.113972368615505, 6.965672368615504], [10.982472368615504, 4.097172368615505], [11.636959430051421, 5.95595943005142], [14.50545943005142, 3.08745943005142], [10.627246491487337, 9.478946491487338], [13.495746491487338, 6.6104464914873375], [14.150233552923256, 8.469233552923255], [17.018733552923255, 5.600733552923255]]

# %% [markdown]
# ```python
# Pontos em que a reta tangente é vertical:
# ```

# %%
# Equacao parametrizada:
# x = 5cos(t) - 3cos(7t/2)
# y = 5sen(t) - 3sen(7t/2)

#Derivada da equacao parametrizada:
# x' = -5sen(t) + 3*7/2*sen(7t/2)
# y' = 5cos(t) - 3*7/2*cos(7t/2)

raizes_vert = []
ult = -1

for t in (np.arange(0, 4*m.pi, 0.0001)):

    xl = -5*m.sin(t) + 3*(7/2)*m.sin(7*t/2)
    yl = 5*m.cos(t) - 3*(7/2)*m.cos(7*t/2)

    # X' = 0 e Y' != 0
    if m.sqrt(xl**2) < 0.01 and m.sqrt(yl**2) > 0.01:
        if t - ult > 0.01:
            ult = t
            raizes_vert.append(t)

raizes_vert
# Out:
# [0.0,
#  0.798,
#  1.9271,
#  2.6247000000000003,
#  3.5374000000000003,
#  4.6290000000000004,
#  5.2662,
#  6.283,
#  7.299600000000001,
#  7.936800000000001,
#  9.0286,
#  9.9411,
#  10.6388,
#  11.768,
#  12.5661]

# %%
# Equacao parametrizada:
# x = 5cos(t) - 3cos(7t/2)
# y = 5sen(t) - 3sen(7t/2)

#Derivada da equacao parametrizada:
# x' = -5sen(t) + 3*7/2*sen(7t/2)
# y' = 5cos(t) - 3*7/2*cos(7t/2)

raizes_hor = []
ult = -1

for t in (np.arange(0, 4*m.pi, 0.0001)):

    xl = -5*m.sin(t) + 3*(7/2)*m.sin(7*t/2)
    yl = 5*m.cos(t) - 3*(7/2)*m.cos(7*t/2)

    if m.sqrt(xl**2) > 0.01 and m.sqrt(yl**2) < 0.01:
        if t - ult > 0.01:
            ult = t
            raizes_hor.append(t)

raizes_hor
# Out:
# [0.3143,
#  1.373,
#  2.3402000000000003,
#  3.0011,
#  4.1163,
#  4.9715,
#  5.7161,
#  6.849900000000001,
#  7.5943000000000005,
#  8.4497,
#  9.5648,
#  10.2256,
#  11.193000000000001,
#  12.2516]

# %%
Pontos_part2 = {}

# %%
for hor in raizes_hor:
    x = 5 * m.cos(hor) - 3 * m.cos(7*hor/2)
    y = 5 * m.sin(hor) - 3 * m.sin(7*hor/2)
    plt.plot(x, y, 'bo')

for vert in raizes_vert:
    x = 5 * m.cos(vert) - 3 * m.cos(7*vert/2)
    y = 5 * m.sin(vert) - 3 * m.sin(7*vert/2)
    plt.plot(x, y, 'go')

#Curva
x,y = fazGraf()
plt.plot(x, y)
plt.axis('equal')
plt.show()
